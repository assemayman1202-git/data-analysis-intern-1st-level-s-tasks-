# %% [markdown]
# <a href="https://colab.research.google.com/github/assemayman1202-git/data-analysis-intern-1st-level-s-tasks-/blob/main/Task_(1%2C2%2C3)_lev_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1 level 1

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("house Prediction Data Set.csv",header= None,names=['CRIM', 'Zone', 'Industry', 'Charles River',
              'Nitric Oxide',
              'Rooms', 'AGE', 'Distance', 'Radial Highways', 'TAX',
              'Pupil-Teacher Ratio', 'Black Population', 'Lower Status', 'Median Value'])

# %%
df
# Out:
#         CRIM  Zone  Industry  Charles River  Nitric Oxide  Rooms   AGE  \
# NaN  0.00632  18.0      2.31            0.0         0.538  6.575  65.2
# NaN  0.02731   0.0      7.07            0.0         0.469  6.421  78.9
# NaN  0.02729   0.0      7.07            0.0         0.469  7.185  61.1
# NaN  0.03237   0.0      2.18            0.0         0.458  6.998  45.8
# NaN  0.06905   0.0      2.18            0.0         0.458  7.147  54.2
# ..       ...   ...       ...            ...           ...    ...   ...
# NaN  0.06263   0.0     11.93            0.0         0.573  6.593  69.1
# NaN  0.04527   0.0     11.93            0.0         0.573  6.120  76.7
# NaN  0.06076   0.0     11.93            0.0         0.573  6.976  91.0
# NaN  0.10959   0.0     11.93            0.0         0.573  6.794  89.3
# NaN  0.04741   0.0     11.93            0.0         0.573  6.030  80.8
#
#      Distance  Radial Highways    TAX  Pupil-Teacher Ratio  Black Population  \
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#         CRIM  Zone  Industry  Charles River  Nitric Oxide  Rooms   AGE  \
# 0    0.00632  18.0      2.31            0.0         0.538  6.575  65.2
# 1    0.02731   0.0      7.07            0.0         0.469  6.421  78.9
# 2    0.02729   0.0      7.07            0.0         0.469  7.185  61.1
# 3    0.03237   0.0      2.18            0.0         0.458  6.998  45.8
# 4    0.06905   0.0      2.18            0.0         0.458  7.147  54.2
# ..       ...   ...       ...            ...           ...    ...   ...
# 501  0.06263   0.0     11.93            0.0         0.573  6.593  69.1
# 502  0.04527   0.0     11.93            0.0         0.573  6.120  76.7
# 503  0.06076   0.0     11.93            0.0         0.573  6.976  91.0
# 504  0.10959   0.0     11.93            0.0         0.573  6.794  89.3
# 505  0.04741   0.0     11.93            0.0         0.573  6.030  80.8
#
#      Distance  Radial Highways    TAX  Pupil-Teacher Ratio  Black Population  \
# ...

# %%
                      ### column names explanation
## CRIM : Crime Rate
# ZN : Zone  نسبة الأراضي المخصصة للسكن الكبير
# INDUS : Industry  نسبة الأراضي التجارية والصناعية في المنطقة
# CHAS : Charles River هل البيت قريب من نهر
# NOX : Nitric Oxide تركيز ثاني أكسيد النيتروجين في الهواء
# RM : Rooms  متوسط عدد الأوض في البيت
# AGE : Age  نسبة البيوت القديمة اللي اتبنت قبل 1940
# DIS : Distance  المسافة لأقرب مراكز عمل في بوسطن
# RAD : Radial Highways سهولة الوصول للطرق السريعة
# TAX : Tax Rate   معدل ضريبة الممتلكات لكل  $10,000
# PTRATIO : Pupil-Teacher Ratio  نسبة الطلاب للمدرسين في المنطقة
# B : Black Population  نسبة السكان السود في المنطقة
#  LSTAT : Lower Status نسبة السكان الفقراء أو محدودي التعليم
# MEDV : Median Value     سعر البيت بالـ $1000 —Target اللي هنتنبأ بيه

# %% [markdown]
# checking missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CRIM                 506 non-null    float64
#  1   Zone                 506 non-null    float64
#  2   Industry             506 non-null    float64
#  3   Charles River        506 non-null    float64
#  4   Nitric Oxide         506 non-null    float64
#  5   Rooms                506 non-null    float64
#  6   AGE                  506 non-null    float64
#  7   Distance             506 non-null    float64
#  8   Radial Highways      506 non-null    int64
#  9   TAX                  506 non-null    float64
#  10  Pupil-Teacher Ratio  506 non-null    float64
#  11  Black Population     506 non-null    float64
#  12  Lower Status         506 non-null    float64
#  13  Median Value         452 non-null    float64
# dtypes: float64(13), int64(1)
# memory usage: 55.5 KB

# %%
df.isnull().sum()
# Out:
# CRIM                    0
# Zone                    0
# Industry                0
# Charles River           0
# Nitric Oxide            0
# Rooms                   0
# AGE                     0
# Distance                0
# Radial Highways         0
# TAX                     0
# Pupil-Teacher Ratio     0
# Black Population        0
# Lower Status            0
# Median Value           54
# dtype: int64

# %%
df.isna().sum()
# Out:
# CRIM                    0
# Zone                    0
# Industry                0
# Charles River           0
# Nitric Oxide            0
# Rooms                   0
# AGE                     0
# Distance                0
# Radial Highways         0
# TAX                     0
# Pupil-Teacher Ratio     0
# Black Population        0
# Lower Status            0
# Median Value           54
# dtype: int64

# %%
df.head(10)
# Out:
#       CRIM  Zone  Industry  Charles River  Nitric Oxide  Rooms    AGE  \
# 0  0.00632  18.0      2.31            0.0         0.538  6.575   65.2
# 1  0.02731   0.0      7.07            0.0         0.469  6.421   78.9
# 2  0.02729   0.0      7.07            0.0         0.469  7.185   61.1
# 3  0.03237   0.0      2.18            0.0         0.458  6.998   45.8
# 4  0.06905   0.0      2.18            0.0         0.458  7.147   54.2
# 5  0.02985   0.0      2.18            0.0         0.458  6.430   58.7
# 6  0.08829  12.5      7.87            0.0         0.524  6.012   66.6
# 7  0.14455  12.5      7.87            0.0         0.524  6.172   96.1
# 8  0.21124  12.5      7.87            0.0         0.524  5.631  100.0
# 9  0.17004  12.5      7.87            0.0         0.524  6.004   85.9
#
#    Distance  Radial Highways    TAX  Pupil-Teacher Ratio  Black Population  \
# 0    4.0900                1  296.0                 15.3            396.90
# ...

# %%
df['Median Value'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 506 entries, 0 to 505
# Series name: Median Value
# Non-Null Count  Dtype
# --------------  -----
# 452 non-null    float64
# dtypes: float64(1)
# memory usage: 4.1 KB

# %%
df['Median Value'].dropna()
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: Median Value, Length: 452, dtype: float64

# %%
df.dropna(subset =['Median Value'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 452 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CRIM                 452 non-null    float64
#  1   Zone                 452 non-null    float64
#  2   Industry             452 non-null    float64
#  3   Charles River        452 non-null    float64
#  4   Nitric Oxide         452 non-null    float64
#  5   Rooms                452 non-null    float64
#  6   AGE                  452 non-null    float64
#  7   Distance             452 non-null    float64
#  8   Radial Highways      452 non-null    int64
#  9   TAX                  452 non-null    float64
#  10  Pupil-Teacher Ratio  452 non-null    float64
#  11  Black Population     452 non-null    float64
#  12  Lower Status         452 non-null    float64
#  13  Median Value         452 non-null    float64
# dtypes: float64(13), int64(1)
# memory usage: 53.0 KB

# %% [markdown]
# change data type

# %%
## change data type
df['Charles River']  = df['Charles River'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 452 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CRIM                 452 non-null    float64
#  1   Zone                 452 non-null    float64
#  2   Industry             452 non-null    float64
#  3   Charles River        452 non-null    int64
#  4   Nitric Oxide         452 non-null    float64
#  5   Rooms                452 non-null    float64
#  6   AGE                  452 non-null    float64
#  7   Distance             452 non-null    float64
#  8   Radial Highways      452 non-null    int64
#  9   TAX                  452 non-null    float64
#  10  Pupil-Teacher Ratio  452 non-null    float64
#  11  Black Population     452 non-null    float64
#  12  Lower Status         452 non-null    float64
#  13  Median Value         452 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 53.0 KB

# %% [markdown]
# check duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.shape)
# Out:
# (452, 14)

# %% [markdown]
# Task 2 level 1 (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.describe()
# Out:
#              CRIM        Zone    Industry  Charles River  Nitric Oxide  \
# count  452.000000  452.000000  452.000000     452.000000    452.000000
# mean     1.420825   12.721239   10.304889       0.077434      0.540816
# std      2.495894   24.326032    6.797103       0.267574      0.113816
# min      0.006320    0.000000    0.460000       0.000000      0.385000
# 25%      0.069875    0.000000    4.930000       0.000000      0.447000
# 50%      0.191030    0.000000    8.140000       0.000000      0.519000
# 75%      1.211460   20.000000   18.100000       0.000000      0.605000
# max      9.966540  100.000000   27.740000       1.000000      0.871000
#
#             Rooms         AGE    Distance  Radial Highways         TAX  \
# count  452.000000  452.000000  452.000000       452.000000  452.000000
# mean     6.343538   65.557965    4.043570         7.823009  377.442478
# std      0.666808   28.127025    2.090492         7.543494  151.327573
# ...

# %%
df.hist(figsize=(15,15),bins=50)
# Out:
# array([[<Axes: title={'center': 'CRIM'}>,
#         <Axes: title={'center': 'Zone'}>,
#         <Axes: title={'center': 'Industry'}>,
#         <Axes: title={'center': 'Charles River'}>],
#        [<Axes: title={'center': 'Nitric Oxide'}>,
#         <Axes: title={'center': 'Rooms'}>,
#         <Axes: title={'center': 'AGE'}>,
#         <Axes: title={'center': 'Distance'}>],
#        [<Axes: title={'center': 'Radial Highways'}>,
#         <Axes: title={'center': 'TAX'}>,
#         <Axes: title={'center': 'Pupil-Teacher Ratio'}>,
#         <Axes: title={'center': 'Black Population'}>],
#        [<Axes: title={'center': 'Lower Status'}>,
#         <Axes: title={'center': 'Median Value'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
fig, axes = plt.subplots(2, 7, figsize=(20, 12))
axes = axes.flatten()

for i, col in enumerate(df.columns):
    df.boxplot(column=col, ax=axes[i])
    axes[i].set_title(col)

# %%
plt.figure(figsize=(14, 12))
sns.heatmap(df.corr(),
            annot=True,
            fmt='.2f',
            cmap='coolwarm',
            linewidths=0.5,
            vmin=-1, vmax=1,
            )

plt.title('Correlation Heatmap', fontsize=16)
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(data=df, x='Rooms', y='Median Value')
# Out:
# <Axes: xlabel='Rooms', ylabel='Median Value'>

# %%
sns.scatterplot(data=df, x='CRIM', y='Median Value')
# Out:
# <Axes: xlabel='CRIM', ylabel='Median Value'>

# %%
sns.scatterplot(data=df, x='Distance', y='Median Value')
# Out:
# <Axes: xlabel='Distance', ylabel='Median Value'>
